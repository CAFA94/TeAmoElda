# %% [markdown]
# # Una historia de amor que durará por siempre ...
#
# <table border="0" width="95%" height="auto"><tr>
# <td><center><img src="Elda1.jpg" border="0"></center></td>
# <td><center><img src="Elda8.jpg" border="0"></center></td>
# <td><center><img src="Elda10.jpg" border="0"></center></td>
# </tr></table>

# %% [markdown]
# ### Elda sé que he cometido errores, y me siento fatal por eso, pero también sé que puedo darte todo de mi, ser aquél que siempre esperaste:
#
# <table border="0" width="95%" height="auto"><tr>
# <td><center><img src="Elda12.jpg" border="0"></center></td>
# <td><center><img src="Elda4.jpg" border="0"></center></td>
# <td><center><img src="Elda24.jpg" border="0"></center></td>
# </tr></table>

# %% [markdown]
# ### Sabes, últimamente he aprendido algunas cosas (tanto a nivel personal y profesional) y moría de ganas por hacerte algo a mi estilo:
# #### (Ignora el código XD jaja)

# %%
'''
=================================
3D heart shape in matplotlib
=================================
'''
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import numpy as np
from skimage import measure

# Set up mesh
n = 100 
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
z = np.linspace(-3,3,n)
X, Y, Z =  np.meshgrid(x, y, z)

# Create cardioid function 
def f_heart(x,y,z):
    F = 320 * ((-x**2 * z**3 -9*y**2 * z**3/80) +
               (x**2 + 9*y**2/4 + z**2-1)**3)
    return F
# Obtain value to at every point in mesh
vol = f_heart(X,Y,Z) 

# Extract a 2D surface mesh from a 3D volume (F=0)
verts, faces ,_ ,_ = measure.marching_cubes_lewiner(vol, 0, spacing=(0.1, 0.1, 0.1))

# Create a 3D figure
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_trisurf(verts[:, 0], verts[:,1], faces, verts[:, 2],
                cmap='Spectral', lw=1)

# Change the angle of view and title
ax.view_init(15, -15)

# ax.set_title(u"Made with ❤ (and Python)", fontsize=15) # if you have Python 3
ax.set_title("Te Amo Elda", fontsize=15)

# Show me some love ^^
plt.show()

# %% [markdown]
# ### No pienso dejarte ir, y estoy decidido a no hacerlo:
#
# <a href="https://www.youtube.com/watch?v=cY9yi9U7AZs&start_radio=1&list=RDcY9yi9U7AZs"> Tengo ganas de gritarte que te extraño ... que cuando te fuiste entonces entendí ... que los grandes cambios no se llevan años ...  que bastó con un segundo junto a tí ...</a>

# %% [markdown]
# <table border="0" width="95%" height="auto"><tr>
# <td><center><img src="Elda22.jpg" border="0"></center></td>
# <td><center><img src="Elda28.jpg" border="0"></center></td>
# <td><center><img src="Elda21.jpg" border="0"></center></td>
# </tr></table>

# %% [markdown]
# ## Te quiero seguir a donde vayas ... (perdóname)

# %% [markdown]
# ### Continuara ...
